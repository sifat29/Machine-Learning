# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df1 = pd.read_json('/content/drive/MyDrive/office dataset/Annotaion_json_files/Bulbuli_After_31_March/CowID_642_S1006_22_03_31_14_to_22_04_01_08.json')
df2 = pd.read_json('/content/drive/MyDrive/office dataset/Annotaion_json_files/Bulbuli_After_31_March/CowID_642_S1006_22_04_01_14_to_22_03_02_08.json')
df3 = pd.read_json('/content/drive/MyDrive/office dataset/Annotaion_json_files/Bulbuli_After_31_March/CowID_642_S1006_22_04_02_15_to_22_04_03_15.json')
df4 = pd.read_json('/content/drive/MyDrive/office dataset/Annotaion_json_files/Bulbuli_After_31_March/CowID_642_S1006_22_04_03_16_to_22_04_04_15.json')
df5 = pd.read_json('/content/drive/MyDrive/office dataset/Annotaion_json_files/Bulbuli_After_31_March/CowID_642_S1006_22_04_04_16_to_22_04_05_19.json')
df6 = pd.read_json('/content/drive/MyDrive/office dataset/Annotaion_json_files/Bulbuli_After_31_March/CowID_642_S1006_22_04_05_20_to_22_04_06_23.json')

# %%
df = pd.concat([df1,df2, df3,df4,df5,df6],           # Append DataFrames
                      ignore_index = True,
                      sort = False)

# %%
print(df)
# Out:
#                      timestamp   x   y   z  rumination  standing  eating
# 0      2022-03-31 13:53:37.000 -57 -71 -34           0         0       0
# 1      2022-03-31 13:53:37.500 -51 -38  -9           0         0       0
# 2      2022-03-31 13:53:38.000 -48 -37 -11           0         0       0
# 3      2022-03-31 13:53:38.500 -49 -38 -12           0         0       0
# 4      2022-03-31 13:53:39.000 -50 -38 -14           0         0       0
# ...                        ...  ..  ..  ..         ...       ...     ...
# 775951 2022-04-06 17:59:57.500 -38 -46 -14           0         0       0
# 775952 2022-04-06 17:59:58.000 -37 -49 -15           0         0       0
# 775953 2022-04-06 17:59:58.500 -38 -49 -14           0         0       0
# 775954 2022-04-06 17:59:59.000 -37 -46 -16           0         0       0
# 775955 2022-04-06 17:59:59.500 -40 -47 -16           0         0       0
#
# [775956 rows x 7 columns]

# %%
df["timestamp"] = df["timestamp"].astype('string') 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 775956 entries, 0 to 775955
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   timestamp   775956 non-null  string
#  1   x           775956 non-null  int64
#  2   y           775956 non-null  int64
#  3   z           775956 non-null  int64
#  4   rumination  775956 non-null  int64
#  5   standing    775956 non-null  int64
#  6   eating      775956 non-null  int64
# dtypes: int64(6), string(1)
# memory usage: 41.4 MB

# %%
df[['Date','Time']] = df.timestamp.str.split(expand=True)
df.drop("timestamp", axis=1, inplace=True)

# %%
print(df)
# Out:
#          x   y   z  rumination  standing  eating        Date          Time
# 0      -57 -71 -34           0         0       0  2022-03-31  13:53:37.000
# 1      -51 -38  -9           0         0       0  2022-03-31  13:53:37.500
# 2      -48 -37 -11           0         0       0  2022-03-31  13:53:38.000
# 3      -49 -38 -12           0         0       0  2022-03-31  13:53:38.500
# 4      -50 -38 -14           0         0       0  2022-03-31  13:53:39.000
# ...     ..  ..  ..         ...       ...     ...         ...           ...
# 775951 -38 -46 -14           0         0       0  2022-04-06  17:59:57.500
# 775952 -37 -49 -15           0         0       0  2022-04-06  17:59:58.000
# 775953 -38 -49 -14           0         0       0  2022-04-06  17:59:58.500
# 775954 -37 -46 -16           0         0       0  2022-04-06  17:59:59.000
# 775955 -40 -47 -16           0         0       0  2022-04-06  17:59:59.500
#
# [775956 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 775956 entries, 0 to 775955
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   x           775956 non-null  int64
#  1   y           775956 non-null  int64
#  2   z           775956 non-null  int64
#  3   rumination  775956 non-null  int64
#  4   standing    775956 non-null  int64
#  5   eating      775956 non-null  int64
#  6   Date        775956 non-null  string
#  7   Time        775956 non-null  string
# dtypes: int64(6), string(2)
# memory usage: 47.4 MB

# %%
df1 = df[df['Date'] == "2022-03-31"]
print(df1)
# Out:
#         x   y   z  rumination  standing  eating        Date          Time
# 0     -57 -71 -34           0         0       0  2022-03-31  13:53:37.000
# 1     -51 -38  -9           0         0       0  2022-03-31  13:53:37.500
# 2     -48 -37 -11           0         0       0  2022-03-31  13:53:38.000
# 3     -49 -38 -12           0         0       0  2022-03-31  13:53:38.500
# 4     -50 -38 -14           0         0       0  2022-03-31  13:53:39.000
# ...    ..  ..  ..         ...       ...     ...         ...           ...
# 70533 -62  -9  -3           0         0       0  2022-03-31  23:59:57.500
# 70534 -64  -5   0           0         0       0  2022-03-31  23:59:58.000
# 70535 -46  -5 -29           0         0       0  2022-03-31  23:59:58.500
# 70536 -70  24  -6           0         0       0  2022-03-31  23:59:59.000
# 70537 -52 -10 -20           0         0       0  2022-03-31  23:59:59.500
#
# [70538 rows x 8 columns]

# %%
count0=(df1['rumination'] == 0).sum()
count1=(df1['rumination'] == 1).sum()
print("count 0=", count0)
print("count 1=", count1)
# Out:
# count 0= 42642
# count 1= 27896

# %%
x=count1/(count0+count1)*100
y= "{:.2f}".format(x)
print(y)
# Out:
# 39.55

# %%
df2 = df[df['Date'] == "2022-04-01"]

# %%
print(df2)
# Out:
#          x   y   z  rumination  standing  eating        Date          Time
# 70538  -64 -14  -7           0         0       0  2022-04-01  00:00:00.000
# 70539  -63 -14  -1           0         0       0  2022-04-01  00:00:00.500
# 70540  -59 -14  -4           0         0       0  2022-04-01  00:00:01.000
# 70541  -61  -9  -3           0         0       0  2022-04-01  00:00:01.500
# 70542  -59  -8  -3           0         0       0  2022-04-01  00:00:02.000
# ...     ..  ..  ..         ...       ...     ...         ...           ...
# 179903 -53 -33 -11           0         1       0  2022-04-01  23:59:57.500
# 179904 -51 -33  -6           0         1       0  2022-04-01  23:59:58.000
# 179905 -54 -23  -3           0         1       0  2022-04-01  23:59:58.500
# 179906 -61  -8  -1           0         1       0  2022-04-01  23:59:59.000
# 179907 -67  -3   1           0         1       0  2022-04-01  23:59:59.500
#
# [109370 rows x 8 columns]

# %%
count0=(df2['rumination'] == 0).sum()
count1=(df2['rumination'] == 1).sum()
print("count 0=", count0)
print("count 1=", count1)
x=count1/(count0+count1)*100
y= "{:.2f}".format(x)
print(y)
# Out:
# count 0= 78278
# count 1= 31092
# 28.43

# %%
df3 = df[df['Date'] == "2022-04-02"]
print(df3)
# Out:
#          x   y   z  rumination  standing  eating        Date          Time
# 179908 -62  -5   2           0         1       0  2022-04-02  00:00:00.000
# 179909 -65  -9   1           0         1       0  2022-04-02  00:00:00.500
# 179910 -59 -16  -3           0         1       0  2022-04-02  00:00:01.000
# 179911 -54 -28  -8           0         1       0  2022-04-02  00:00:01.500
# 179912 -53 -29  -8           0         1       0  2022-04-02  00:00:02.000
# ...     ..  ..  ..         ...       ...     ...         ...           ...
# 271721 -46 -41 -11           1         0       0  2022-04-02  23:59:57.500
# 271722 -44 -43  -9           1         0       0  2022-04-02  23:59:58.000
# 271723 -46 -44 -13           1         0       0  2022-04-02  23:59:58.500
# 271724 -47 -40 -10           0         0       0  2022-04-02  23:59:59.000
# 271725 -47 -41 -11           0         0       0  2022-04-02  23:59:59.500
#
# [91818 rows x 8 columns]

# %%
count0=(df3['rumination'] == 0).sum()
count1=(df3['rumination'] == 1).sum()
print("count 0=", count0)
print("count 1=", count1)
x=count1/(count0+count1)*100
y= "{:.2f}".format(x)
print(y)
# Out:
# count 0= 60190
# count 1= 31628
# 34.45

# %%
df4 = df[df['Date'] == "2022-04-03"]
print(df4)
# Out:
#          x   y   z  rumination  standing  eating        Date          Time
# 271726 -45 -43 -12           0         0       0  2022-04-03  00:00:00.000
# 271727 -45 -41  -9           0         0       0  2022-04-03  00:00:00.500
# 271728 -47 -41 -13           0         0       0  2022-04-03  00:00:01.000
# 271729 -48 -40 -10           0         0       0  2022-04-03  00:00:01.500
# 271730 -40 -47 -10           0         0       0  2022-04-03  00:00:02.000
# ...     ..  ..  ..         ...       ...     ...         ...           ...
# 424918 -58 -19  -6           0         1       0  2022-04-03  23:59:57.500
# 424919 -58 -19  -7           0         1       0  2022-04-03  23:59:58.000
# 424920 -59 -19  -7           0         1       0  2022-04-03  23:59:58.500
# 424921 -59 -19  -8           0         1       0  2022-04-03  23:59:59.000
# 424922 -59 -18  -9           0         1       0  2022-04-03  23:59:59.500
#
# [153197 rows x 8 columns]

# %%
count0=(df4['rumination'] == 0).sum()
count1=(df4['rumination'] == 1).sum()
print("count 0=", count0)
print("count 1=", count1)
x=count1/(count0+count1)*100
y= "{:.2f}".format(x)
print(y)
# Out:
# count 0= 118921
# count 1= 34276
# 22.37

# %%
df5 = df[df['Date'] == "2022-04-04"]
print(df5)
count0=(df5['rumination'] == 0).sum()
count1=(df5['rumination'] == 1).sum()
print("count 0=", count0)
print("count 1=", count1)
x=count1/(count0+count1)*100
y= "{:.2f}".format(x)
print(y)
# Out:
#          x   y   z  rumination  standing  eating        Date          Time
# 424923 -58 -19  -9           0         1       0  2022-04-04  00:00:00.000
# 424924 -59 -19  -8           0         1       0  2022-04-04  00:00:00.500
# 424925 -58 -20  -9           0         1       0  2022-04-04  00:00:01.000
# 424926 -59 -19  -8           0         1       0  2022-04-04  00:00:01.500
# 424927 -58 -20  -8           0         1       0  2022-04-04  00:00:02.000
# ...     ..  ..  ..         ...       ...     ...         ...           ...
# 538530 -55 -27  -8           0         1       0  2022-04-04  23:59:57.500
# 538531 -56 -27 -10           0         1       0  2022-04-04  23:59:58.000
# 538532 -56 -27 -11           0         1       0  2022-04-04  23:59:58.500
# 538533 -55 -27 -10           0         1       0  2022-04-04  23:59:59.000
# 538534 -54 -27  -9           0         1       0  2022-04-04  23:59:59.500
#
# [113612 rows x 8 columns]
# count 0= 87028
# count 1= 26584
# 23.40

# %%
df6 = df[df['Date'] == "2022-04-05"]
print(df6)
count0=(df6['rumination'] == 0).sum()
count1=(df6['rumination'] == 1).sum()
print("count 0=", count0)
print("count 1=", count1)
x=count1/(count0+count1)*100
y= "{:.2f}".format(x)
print(y)
# Out:
#          x   y   z  rumination  standing  eating        Date          Time
# 538535 -54 -27 -11           0         1       0  2022-04-05  00:00:00.000
# 538536 -55 -28 -11           0         1       0  2022-04-05  00:00:00.500
# 538537 -56 -27 -10           0         1       0  2022-04-05  00:00:01.000
# 538538 -57 -27 -10           0         1       0  2022-04-05  00:00:01.500
# 538539 -56 -28 -11           0         1       0  2022-04-05  00:00:02.000
# ...     ..  ..  ..         ...       ...     ...         ...           ...
# 685757 -60 -19  -6           0         1       1  2022-04-05  23:59:57.500
# 685758 -63 -12  -6           0         1       1  2022-04-05  23:59:58.000
# 685759 -49  23  13           0         1       1  2022-04-05  23:59:58.500
# 685760 -58   8  12           0         1       1  2022-04-05  23:59:59.000
# 685761 -57  -2  10           0         1       1  2022-04-05  23:59:59.500
#
# [147227 rows x 8 columns]
# count 0= 114858
# count 1= 32369
# 21.99

# %%
df7 = df[df['Date'] == "2022-04-06"]
print(df7)
count0=(df7['rumination'] == 0).sum()
count1=(df7['rumination'] == 1).sum()
print("count 0=", count0)
print("count 1=", count1)
x=count1/(count0+count1)*100
y= "{:.2f}".format(x)
print(y)
# Out:
#          x   y   z  rumination  standing  eating        Date          Time
# 685762 -62   1   6           0         1       1  2022-04-06  00:00:00.000
# 685763 -67   1   0           0         1       1  2022-04-06  00:00:00.500
# 685764 -56  13  -7           0         1       1  2022-04-06  00:00:01.000
# 685765 -48  23 -10           0         1       1  2022-04-06  00:00:01.500
# 685766 -59   7  -7           0         1       1  2022-04-06  00:00:02.000
# ...     ..  ..  ..         ...       ...     ...         ...           ...
# 775951 -38 -46 -14           0         0       0  2022-04-06  17:59:57.500
# 775952 -37 -49 -15           0         0       0  2022-04-06  17:59:58.000
# 775953 -38 -49 -14           0         0       0  2022-04-06  17:59:58.500
# 775954 -37 -46 -16           0         0       0  2022-04-06  17:59:59.000
# 775955 -40 -47 -16           0         0       0  2022-04-06  17:59:59.500
#
# [90194 rows x 8 columns]
# count 0= 72794
# count 1= 17400
# 19.29
