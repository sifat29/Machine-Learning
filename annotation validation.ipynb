# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel (r'/content/drive/MyDrive/office dataset for tesing/CowID_642_S1006_22_04_26.xlsx')
print (df)
# Out:
#        device_id     timestamp            date_time   x       x_g   y  \
# 0          S1006  1.650928e+09  26/04/2022-05:00:00 -51 -7.817344 -27
# 1          S1006  1.650928e+09  26/04/2022-05:00:00 -51 -7.817344 -25
# 2          S1006  1.650928e+09  26/04/2022-05:00:01 -49 -7.510781 -22
# 3          S1006  1.650928e+09  26/04/2022-05:00:01 -47 -7.204219 -29
# 4          S1006  1.650928e+09  26/04/2022-05:00:02 -52 -7.970625 -27
# ...          ...           ...                  ...  ..       ...  ..
# 124809     S1006  1.650996e+09  26/04/2022-23:59:57 -49 -7.510781 -26
# 124810     S1006  1.650996e+09  26/04/2022-23:59:58 -52 -7.970625 -27
# 124811     S1006  1.650996e+09  26/04/2022-23:59:58 -56 -8.583750 -24
# 124812     S1006  1.650996e+09  26/04/2022-23:59:59 -52 -7.970625 -25
# 124813     S1006  1.650996e+09  26/04/2022-23:59:59 -54 -8.277188 -27
#
#              y_g   z       z_g  rumination  standing  eating
# 0      -4.138594 -28 -4.291875           1         1       0
# ...

# %%
df.dropna(inplace=True)
df[['rumination', 'eating', 'standing']] = df[['rumination', 'eating', 'standing']].astype(int)
print('Wrong annotation: ',(df['rumination'].values & df['eating'].values).sum())
# Out:
# Wrong annotation:  54

# %%
count0=(df['rumination'] == 0).sum()
count1=(df['rumination'] == 1).sum()
print("count 0=", count0)
print("count 1=", count1)
# Out:
# count 0= 102924
# count 1= 21890

# %%
print('rumination percentage =',count1/(count0+count1)*100,'%')
# Out:
# rumination percentage = 17.53809668787155 %
