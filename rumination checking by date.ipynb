# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_json('/content/drive/MyDrive/office dataset for tesing/CowID_642_S1006_22_04_24_to_22_04_26.json')
#df2 = pd.read_json('/content/drive/MyDrive/office dataset/Annotaion_json_files/Bulbuli_11_March_14_March/CowID_642_S1006_03_12_2022.json')
#df3 = pd.read_json('/content/drive/MyDrive/office dataset/Annotaion_json_files/Bulbuli_11_March_14_March/CowID_642_S1006_03_13_2022.json')
#df4 = pd.read_json('/content/drive/MyDrive/office dataset/Annotaion_json_files/Bulbuli_11_March_14_March/CowID_642_S1006_03_14_2022.json')

# %%
#df = pd.concat([df1,df2, df3,df4],           # Append DataFrames
                      ignore_index = True,
                      sort = False)

# %%
print(df)
# Out:
#                      timestamp   x   y   z  rumination  standing  eating
# 0      2022-04-23 20:32:31.000 -20 -52 -30           0         0       0
# 1      2022-04-23 20:32:31.500 -22 -52 -31           0         0       0
# 2      2022-04-23 20:32:32.000 -22 -50 -32           0         0       0
# 3      2022-04-23 20:32:32.500 -21 -53 -29           0         0       0
# 4      2022-04-23 20:32:33.000 -21 -51 -32           0         0       0
# ...                        ...  ..  ..  ..         ...       ...     ...
# 368555 2022-04-26 17:59:57.500 -49 -26 -23           1         1       0
# 368556 2022-04-26 17:59:58.000 -52 -27 -29           1         1       0
# 368557 2022-04-26 17:59:58.500 -56 -24 -21           1         1       0
# 368558 2022-04-26 17:59:59.000 -52 -25 -22           1         1       0
# 368559 2022-04-26 17:59:59.500 -54 -27 -20           1         1       0
#
# [368560 rows x 7 columns]

# %%
df["timestamp"] = df["timestamp"].astype('string') 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 368560 entries, 0 to 368559
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   timestamp   368560 non-null  string
#  1   x           368560 non-null  int64
#  2   y           368560 non-null  int64
#  3   z           368560 non-null  int64
#  4   rumination  368560 non-null  int64
#  5   standing    368560 non-null  int64
#  6   eating      368560 non-null  int64
# dtypes: int64(6), string(1)
# memory usage: 22.5 MB

# %%
df[['Date','Time']] = df.timestamp.str.split(expand=True)
df.drop("timestamp", axis=1, inplace=True)

# %%
print(df)
# Out:
#          x   y   z  rumination  standing  eating        Date          Time
# 0      -20 -52 -30           0         0       0  2022-04-23  20:32:31.000
# 1      -22 -52 -31           0         0       0  2022-04-23  20:32:31.500
# 2      -22 -50 -32           0         0       0  2022-04-23  20:32:32.000
# 3      -21 -53 -29           0         0       0  2022-04-23  20:32:32.500
# 4      -21 -51 -32           0         0       0  2022-04-23  20:32:33.000
# ...     ..  ..  ..         ...       ...     ...         ...           ...
# 368555 -49 -26 -23           1         1       0  2022-04-26  17:59:57.500
# 368556 -52 -27 -29           1         1       0  2022-04-26  17:59:58.000
# 368557 -56 -24 -21           1         1       0  2022-04-26  17:59:58.500
# 368558 -52 -25 -22           1         1       0  2022-04-26  17:59:59.000
# 368559 -54 -27 -20           1         1       0  2022-04-26  17:59:59.500
#
# [368560 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 368560 entries, 0 to 368559
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   x           368560 non-null  int64
#  1   y           368560 non-null  int64
#  2   z           368560 non-null  int64
#  3   rumination  368560 non-null  int64
#  4   standing    368560 non-null  int64
#  5   eating      368560 non-null  int64
#  6   Date        368560 non-null  string
#  7   Time        368560 non-null  string
# dtypes: int64(6), string(2)
# memory usage: 25.3 MB

# %%
df1 = df[df['Date'] == "2022-04-23"]
print(df1)
# Out:
#         x   y   z  rumination  standing  eating        Date          Time
# 0     -20 -52 -30           0         0       0  2022-04-23  20:32:31.000
# 1     -22 -52 -31           0         0       0  2022-04-23  20:32:31.500
# 2     -22 -50 -32           0         0       0  2022-04-23  20:32:32.000
# 3     -21 -53 -29           0         0       0  2022-04-23  20:32:32.500
# 4     -21 -51 -32           0         0       0  2022-04-23  20:32:33.000
# ...    ..  ..  ..         ...       ...     ...         ...           ...
# 14987 -49 -26 -23           1         0       0  2022-04-23  22:41:40.500
# 14988 -51 -27 -28           1         0       0  2022-04-23  22:41:41.000
# 14989 -52 -30 -29           1         0       0  2022-04-23  22:41:41.500
# 14990 -52 -30 -29           1         0       0  2022-04-23  22:41:42.000
# 14991 -51 -29 -25           1         0       0  2022-04-23  22:41:42.500
#
# [14992 rows x 8 columns]

# %%
count0=(df1['rumination'] == 0).sum()
count1=(df1['rumination'] == 1).sum()
print("count 0=", count0)
print("count 1=", count1)
# Out:
# count 0= 8710
# count 1= 6282

# %%
x=count1/(count0+count1)*100
y= "{:.2f}".format(x)
print(y)
# Out:
# 41.90

# %%
df2 = df[df['Date'] == "2022-04-24"]

# %%
print(df2)
# Out:
#          x   y   z  rumination  standing  eating        Date          Time
# 14992  -69 -10   4           0         1       1  2022-04-24  00:11:30.000
# 14993  -68  -2   4           0         1       1  2022-04-24  00:11:30.500
# 14994  -73  -6  10           0         1       1  2022-04-24  00:11:31.000
# 14995  -63   5  11           0         1       1  2022-04-24  00:11:31.500
# 14996  -80   7   3           0         1       1  2022-04-24  00:11:32.000
# ...     ..  ..  ..         ...       ...     ...         ...           ...
# 165557 -52 -29 -24           0         0       0  2022-04-24  22:52:18.500
# 165558 -51 -28 -23           0         0       0  2022-04-24  22:52:19.000
# 165559 -52 -29 -22           0         0       0  2022-04-24  22:52:19.500
# 165560 -52 -27 -21           0         0       0  2022-04-24  22:52:20.000
# 165561 -54 -22 -25           0         0       0  2022-04-24  22:52:20.500
#
# [150570 rows x 8 columns]

# %%
count0=(df2['rumination'] == 0).sum()
count1=(df2['rumination'] == 1).sum()
print("count 0=", count0)
print("count 1=", count1)
x=count1/(count0+count1)*100
y= "{:.2f}".format(x)
print(y)
# Out:
# count 0= 119502
# count 1= 31068
# 20.63

# %%
df3 = df[df['Date'] == "2022-04-25"]
print(df3)
# Out:
#          x   y   z  rumination  standing  eating        Date          Time
# 165562 -61   0 -11           0         1       0  2022-04-25  02:57:45.000
# 165563 -60   3 -10           0         1       0  2022-04-25  02:57:45.500
# 165564 -62   1  -9           0         1       0  2022-04-25  02:57:46.000
# 165565 -50  -2   5           0         1       0  2022-04-25  02:57:46.500
# 165566 -61 -17  -1           0         1       0  2022-04-25  02:57:47.000
# ...     ..  ..  ..         ...       ...     ...         ...           ...
# 250747 -57   3  -9           0         1       0  2022-04-25  23:59:57.500
# 250748 -57   6 -13           0         1       0  2022-04-25  23:59:58.000
# 250749 -64  16 -14           0         1       0  2022-04-25  23:59:58.500
# 250750 -56  11  -4           0         1       0  2022-04-25  23:59:59.000
# 250751 -69   0 -12           0         1       0  2022-04-25  23:59:59.500
#
# [85190 rows x 8 columns]

# %%
count0=(df3['rumination'] == 0).sum()
count1=(df3['rumination'] == 1).sum()
print("count 0=", count0)
print("count 1=", count1)
x=count1/(count0+count1)*100
y= "{:.2f}".format(x)
print(y)
# Out:
# count 0= 75372
# count 1= 9818
# 11.52

# %%
df4 = df[df['Date'] == "2022-04-26"]
print(df4)
# Out:
#          x   y   z  rumination  standing  eating        Date          Time
# 250752 -79  -1   8           0         1       1  2022-04-26  00:00:00.000
# 250753 -59 -12 -19           0         1       1  2022-04-26  00:00:00.500
# 250754 -51 -12  -6           0         1       1  2022-04-26  00:00:01.000
# 250755 -66 -18  -8           0         1       1  2022-04-26  00:00:01.500
# 250756 -58 -10  -5           0         1       1  2022-04-26  00:00:02.000
# ...     ..  ..  ..         ...       ...     ...         ...           ...
# 368555 -49 -26 -23           1         1       0  2022-04-26  17:59:57.500
# 368556 -52 -27 -29           1         1       0  2022-04-26  17:59:58.000
# 368557 -56 -24 -21           1         1       0  2022-04-26  17:59:58.500
# 368558 -52 -25 -22           1         1       0  2022-04-26  17:59:59.000
# 368559 -54 -27 -20           1         1       0  2022-04-26  17:59:59.500
#
# [117808 rows x 8 columns]

# %%
count0=(df4['rumination'] == 0).sum()
count1=(df4['rumination'] == 1).sum()
print("count 0=", count0)
print("count 1=", count1)
x=count1/(count0+count1)*100
y= "{:.2f}".format(x)
print(y)
# Out:
# count 0= 96694
# count 1= 21114
# 17.92

# %%
df5 = df[df['Date'] == "2022-03-14"]
print(df5)
count0=(df5['rumination'] == 0).sum()
count1=(df5['rumination'] == 1).sum()
print("count 0=", count0)
print("count 1=", count1)
x=count1/(count0+count1)*100
y= "{:.2f}".format(x)
print(y)
# Out:
#          x   y   z  rumination  standing  eating        Date          Time
# 494048 -57 -14 -11           1         0       0  2022-03-14  00:00:00.000
# 494049 -57 -15 -11           1         0       0  2022-03-14  00:00:00.500
# 494050 -57 -20 -14           1         0       0  2022-03-14  00:00:01.000
# 494051 -57 -16  -3           1         0       0  2022-03-14  00:00:01.500
# 494052 -64  -2  -6           1         0       0  2022-03-14  00:00:02.000
# ...     ..  ..  ..         ...       ...     ...         ...           ...
# 585217 -61  -3  -4           0         0       0  2022-03-14  17:59:56.500
# 585218 -60  -4  -2           0         0       0  2022-03-14  17:59:57.000
# 585219 -61  -4  -5           0         0       0  2022-03-14  17:59:57.500
# 585220 -60  -2  -4           0         0       0  2022-03-14  17:59:58.000
# 585221 -60  -5  -4           0         0       0  2022-03-14  17:59:58.500
#
# [91174 rows x 8 columns]
# count 0= 78367
# count 1= 12807
# 14.05

# %%
df6 = df[df['Date'] == "2022-04-05"]
print(df6)
count0=(df6['rumination'] == 0).sum()
count1=(df6['rumination'] == 1).sum()
print("count 0=", count0)
print("count 1=", count1)
x=count1/(count0+count1)*100
y= "{:.2f}".format(x)
print(y)
# Out:
#          x   y   z  rumination  standing  eating        Date          Time
# 538535 -54 -27 -11           0         1       0  2022-04-05  00:00:00.000
# 538536 -55 -28 -11           0         1       0  2022-04-05  00:00:00.500
# 538537 -56 -27 -10           0         1       0  2022-04-05  00:00:01.000
# 538538 -57 -27 -10           0         1       0  2022-04-05  00:00:01.500
# 538539 -56 -28 -11           0         1       0  2022-04-05  00:00:02.000
# ...     ..  ..  ..         ...       ...     ...         ...           ...
# 685757 -60 -19  -6           0         1       1  2022-04-05  23:59:57.500
# 685758 -63 -12  -6           0         1       1  2022-04-05  23:59:58.000
# 685759 -49  23  13           0         1       1  2022-04-05  23:59:58.500
# 685760 -58   8  12           0         1       1  2022-04-05  23:59:59.000
# 685761 -57  -2  10           0         1       1  2022-04-05  23:59:59.500
#
# [147227 rows x 8 columns]
# count 0= 114858
# count 1= 32369
# 21.99

# %%
df7 = df[df['Date'] == "2022-04-06"]
print(df7)
count0=(df7['rumination'] == 0).sum()
count1=(df7['rumination'] == 1).sum()
print("count 0=", count0)
print("count 1=", count1)
x=count1/(count0+count1)*100
y= "{:.2f}".format(x)
print(y)
# Out:
#          x   y   z  rumination  standing  eating        Date          Time
# 685762 -62   1   6           0         1       1  2022-04-06  00:00:00.000
# 685763 -67   1   0           0         1       1  2022-04-06  00:00:00.500
# 685764 -56  13  -7           0         1       1  2022-04-06  00:00:01.000
# 685765 -48  23 -10           0         1       1  2022-04-06  00:00:01.500
# 685766 -59   7  -7           0         1       1  2022-04-06  00:00:02.000
# ...     ..  ..  ..         ...       ...     ...         ...           ...
# 775951 -38 -46 -14           0         0       0  2022-04-06  17:59:57.500
# 775952 -37 -49 -15           0         0       0  2022-04-06  17:59:58.000
# 775953 -38 -49 -14           0         0       0  2022-04-06  17:59:58.500
# 775954 -37 -46 -16           0         0       0  2022-04-06  17:59:59.000
# 775955 -40 -47 -16           0         0       0  2022-04-06  17:59:59.500
#
# [90194 rows x 8 columns]
# count 0= 72794
# count 1= 17400
# 19.29
